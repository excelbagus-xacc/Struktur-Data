# %% [markdown]
# <a href="https://colab.research.google.com/github/excelbagus-xacc/Struktur-Data/blob/main/Pertemuan4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Queue dengan List

# %%
# Python program to demonstrate queue implementation using list
queue = []

# append() function to enqueue element in the queue
queue.append('a')
queue.append('i')
queue.append('u')
queue.append('e')
queue.append('o')

print('Initial queue')
print(queue)

# pop(0) function to dequeue element from queue in FIFO order
print('\nElements dequeued from queue:')
print(queue.pop(0))
print(queue.pop(0))
print(queue.pop(0))


print('\nQueue after removing elements:')
print(queue)

# uncommenting print(queue.pop()) will cause an IndexError as the queue is now empty
# Out:
# Initial queue
# ['a', 'i', 'u', 'e', 'o']
#
# Elements dequeued from queue:
# a
# i
# u
#
# Queue after removing elements:
# ['e', 'o']

# %% [markdown]
# Queue dengan collection.deque

# %%
# Python program to demonstrate queue implementation using collections.deque
from collections import deque

queue = deque()

# append() function to enqueue element in the queue
queue.append('a')
queue.append('i')
queue.append('u')
queue.append('e')
queue.append('o')

print('Initial queue')
print(queue)

# popleft() function to dequeue element from stack in LIFO order
print('\nElements dequeued from queue:')
print(queue.popleft())
print(queue.popleft())
print(queue.popleft())

print('\nQueue after removing elements:')
print(queue)

# uncommenting print(queue.popleft()) will cause an IndexError as the queue is now empty
# Out:
# Initial queue
# deque(['a', 'i', 'u', 'e', 'o'])
#
# Elements dequeued from queue:
# a
# i
# u
#
# Queue after removing elements:
# deque(['e', 'o'])

# %% [markdown]
# Queue dengan queue.Queue

# %%
# Python program to demonstrate queue implementation using queue.Queue
from queue import Queue

# Initializing a queue
qu = Queue(maxsize=5)

# qsize() show the number of elements in the queue
print(qu.qsize())

# put() function to enqueue element in the queue
qu.put('a')
qu.put('i')
qu.put('u')
qu.put('e')
qu.put('o')

print('Full:', qu.full())
print('Size:', qu.qsize())

# get() function to dequeue element from queue
print('\nElements dequeued from the queue')
print(qu.get())
print(qu.get())
print(qu.get())

print('\nEmpty: ', qu.empty())
print('Full: ', qu.full())
# Out:
# 0
# Full: True
# Size: 5
#
# Elements dequeued from the queue
# a
# i
# u
#
# Empty:  False
# Full:  False

# %% [markdown]
# Queue dengan Single Linked List

# %%
class Queue:
  def __init__(self):
    self.queue = list()

  def addtoqu(self,dataval):
# insert method to add element
    if dataval not in self.queue:
      self.queue.insert(0,dataval)
      return True
    return False

# Pop method the remove element
  def removefromq(self):
    if len(self.queue)>0:
      return self.queue.pop()
    return ('No elements in Queue!')

  def size(self):
    return len(self.queue)

TheQueue = Queue()
print(TheQueue.addtoqu('Jan'))
print(TheQueue.addtoqu('Feb'))
print(TheQueue.addtoqu('March'))
print(TheQueue.addtoqu('April'))
print(TheQueue.size())
print(TheQueue.removefromq())
print(TheQueue.removefromq())
print(TheQueue.size())
# Out:
# True
# True
# True
# True
# 4
# Jan
# Feb
# 2

# %% [markdown]
# **Tugas: Algoritma Pencarian dan Pengurutan dalam Python**

# %% [markdown]
# Linear Search

# %%
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i  # kembalikan indeks jika ditemukan
    return -1  # kembalikan -1 jika tidak ditemukan

data = [10, 25, 7, 42, 13]
hasil = linear_search(data, 42)
print(f"Elemen ditemukan di indeks: {hasil}")
# Out:
# Elemen ditemukan di indeks: 3

# %% [markdown]
# Binary Search

# %%
def binary_search(arr, target):
    kiri, kanan = 0, len(arr) - 1
    while kiri <= kanan:
        tengah = (kiri + kanan) // 2
        if arr[tengah] == target:
            return tengah
        elif arr[tengah] < target:
            kiri = tengah + 1
        else:
            kanan = tengah - 1
    return -1

data = [5, 12, 23, 34, 45, 67, 89]
hasil = binary_search(data, 34)
print(f"Elemen ditemukan di indeks: {hasil}")
# Out:
# Elemen ditemukan di indeks: 3

# %% [markdown]
# Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

data = [64, 34, 25, 12, 22, 11, 90]
print(bubble_sort(data))
# Out:
# [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

data = [29, 10, 14, 37, 13]
print(selection_sort(data))
# Out:
# [10, 13, 14, 29, 37]

# %% [markdown]
# Insertion Sort

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        kunci = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > kunci:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = kunci
    return arr

data = [12, 11, 13, 5, 6]
print(insertion_sort(data))
# Out:
# [5, 6, 11, 12, 13]
