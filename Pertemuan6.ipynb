# %% [markdown]
# <a href="https://colab.research.google.com/github/excelbagus-xacc/Struktur-Data/blob/main/Pertemuan6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bubble Sort

# %%
def bubble_sort(arr):
  n = len(arr)
  for i in range(n - 1):
    for j in range(n - i -1):
      if arr[j] > arr[j + 1]:
        arr[j], arr[j + 1] = arr[j +1], arr[j]
  return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())  # Menggunakan copy agar data asli tidak berubah
print('Data sebelum sorting:', data)
print('Data setelah Bubble Sort:', sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Selection Sort

# %%
def selection_sort(arr):
  n = len(arr)
  for i in range(n - 1):
    min_index = i
    for j in range(i + 1, n):
      if arr[j] < arr[min_index]:
        min_index = j
      arr[i], arr[min_index] = arr[min_index], arr[i]
  return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print('Data sebelum sorting:', data)
print('Data setelah Selection Sort:', sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 22, 12, 25, 64]

# %% [markdown]
# Insertion Sort

# %%
def insertion_sort(arr):
  n = len(arr)
  for i in range(1, n):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j -= 1
    arr[j + 1] = key
  return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print('Data sebelum sorting:', data)
print('Data setelah Insertion Sort:', sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Merge Sort

# %%
def merge_sort(arr):
  if len(arr) > 1:
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[:mid]

    merge_sort(left_half)
    merge_sort(right_half)

    i = j = k = 0

    while i < len(left_half) and j < len(right_half):
      if left_half[i] < right_half[i]:
        arr[k] = left_half[i]
        i += 1
      else:
        arr[k] = right_half[i]
        j += 1
      k += 1

    while i < len(left_half):
      arr[k] = left_half[i]
      i += 1
      k += 1

    while j < len(right_half):
      arr[k] = right_half[i]
      j += 1
      k += 1

  return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print('Data sebelum sorting:', data)
print('Data setelah Merge Sort:', sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [64, 64, 64, 64, 11]

# %% [markdown]
# Quick Sort

# %%
def quick_sort(arr):
  if len(arr) <= 1:
    return arr

  pivot = arr[len(arr) // 2]
  left = [x for x in arr if x < pivot]
  middle = [x for x in arr if x == pivot]
  right = [x for x in arr if x > pivot]

  return quick_sort(left) + middle + quick_sort(right)

data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print('Data sebelum sorting:', data)
print('Data setelah Quick Sort:', sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# **TUGAS**

# %% [markdown]
# Pengurutan Hasil Ujian MAhasiswa (Rombel 03)

# %%
def sort_nilai_mahasiswa(data_nilai):
  # Menggunakan Quick Sort untuk pengurutan Descending
  if len(data_nilai) <= 1:
    return data_nilai

  # Pilih pivot (ambil elemen tengah)
  pivot = data_nilai[len(data_nilai) // 2]['nilai']

  # karena Descending: elemen yang lebih besae diletakkan di 'left'
  left = [x for x in data_nilai if x['nilai'] > pivot]
  middle = [x for x in data_nilai if x['nilai'] == pivot]
  right = [x for x in data_nilai if x['nilai'] < pivot]

  return sort_nilai_mahasiswa(left) + middle + sort_nilai_mahasiswa(right)

# Data Mahasiswa
daftar_nilai = [
    {'nama': 'Bani', 'nilai': 80},
    {'nama': 'Fastya', 'nilai': 85},
    {'nama': 'Ben', 'nilai': 86},
    {'nama': 'Eva', 'nilai': 92},
    {'nama': 'Parker', 'nilai': 95}
]

print('Daftar Nilai Mahasiswa')
hasil_urut = sort_nilai_mahasiswa(daftar_nilai)

for i, mhs in enumerate(hasil_urut, 1):
  print(f'Peringkat {i} {mhs['nama']} - Skor: {mhs['nilai']}')
# Out:
# Daftar Nilai Mahasiswa
# Peringkat 1 Parker - Skor: 95
# Peringkat 2 Eva - Skor: 92
# Peringkat 3 Ben - Skor: 86
# Peringkat 4 Fastya - Skor: 85
# Peringkat 5 Bani - Skor: 80
